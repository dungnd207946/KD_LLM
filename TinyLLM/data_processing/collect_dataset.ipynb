# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..'))) # Lùi 1 cấp để có thể import DataProcessor
from KD import DataProcessor
from transformers import AutoTokenizer


local_model_dir = "./google/gemma-3-270m-it"
tokenizer = AutoTokenizer.from_pretrained(local_model_dir)
processor = DataProcessor(tokenizer)
